# %%
import requests
from bs4 import BeautifulSoup
from tabulate import tabulate
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By

''' 
This program merges all of the separate programs (protagonists.ipynb and synopsis.ipynb) and adds the text search function. It will
return all of the movies that contain family keywords inside a data frame. This program runs in approximately 7-8 mins."
'''

def movie_table(url):
    webpage = url
    response = requests.get(webpage)

    page = response.text

    soup = BeautifulSoup(page, 'html.parser')
    beautiful_page = soup.get_text()

    ratings = []
    years = []
    titles = []
    movie_nums = []

    lines = beautiful_page.splitlines()

    for line in lines:
        if "(20" in line and ")" in line or '(19' in line and ')' in line:
            years.append(line)

    rep_years = []
    nrep_years = []
    year_indices = []

    for year in years:
        
        if lines.count(year) > 1:
            if year not in rep_years:
                rep_years.append(year)
        if lines.count(year) == 1:
            nrep_years.append(year)

    for i in range(len(rep_years)):
        first_instance = lines.index(rep_years[i])
        year_indices.append(first_instance)

        for j, item in enumerate(lines[first_instance+1:], start=first_instance+1):
            if item == rep_years[i]:
                year_indices.append(j)

    for year in nrep_years:
        if year in lines:
            index = lines.index(year)
            year_indices.append(index)


    for index in sorted(year_indices):
        title = lines[index-1]
        titles.append(title)

        rating = lines[index+6]
        ratings.append(rating)

        movie_num = lines[index-3]
        movie_nums.append(movie_num) 
        

    ratings = [rating.lstrip() for rating in ratings]
    for i in range(len(ratings)):
        if ratings[i] == '':
            ratings[i] = "None"


    for i in range(len(years)):
        for j in range(len(years[i])):
            if years[i][j].isnumeric():
                number_index = years[i].find(years[i][j])
                years[i] = years[i][number_index:number_index+4]
                break


    table_data = list(zip(movie_nums, titles, years, ratings))
    # headers = ["Movie Number", "Title", "Year", "Rating"]

    # print(tabulate(table_data, headers=headers))
    
    return table_data

synopsis_list = []

# Function to get the synopsis from every movie in the webpage
def synopses(link):
    webpage = link
    response = requests.get(webpage)

    page = response.text

    soup = BeautifulSoup(page, 'html.parser')

    url_list = []
    movie_url_list = []
    movie_ref_nums = []

    # Get all the hyperlinks
    for link in soup.find_all('a'):
        url_list.append(link.get('href'))

    # Filter to get movie title hyperlinks
    for url in url_list:
        if '/title/tt' in url:
            if url not in movie_url_list:
                movie_url_list.append(url) 

    # Take the reference number from the movie url
    for movie_url in movie_url_list:
        movie_ref_nums.append(movie_url[7:16])


    # Extract the synopsis from every movie then append to a list
    driver = webdriver.Chrome('/Users/nixoncarino/Desktop/chromedriver')

    for i in movie_ref_nums:
        url = "https://www.imdb.com/title/" + i + "/plotsummary/?ref_=tt_stry_pl#synopsis"
        try:
            driver.get(url)
            synopsis_element = driver.find_element(By.XPATH, '//*[@id="__next"]/main/div/section/div/section/div/div[1]/section[2]/div[2]/ul/li/div/div/div/div/div')
        except:
            synopsis_list.append("No Synopsis")
        else:
            synopsis = synopsis_element.text
            synopsis_list.append(synopsis)

# Function that find family related words on the synopsis
def text_search(synopsis_list):
    # The indices of the synopses that contain any of the keywords
    match_index_list = []

    keywords = ["family", "parenting", "father", "mother", "son", "daughter", "sibling", "brother", "sister", "marriage", "divorce", "blended family", "adoption",
                "foster care", "custody", "inheritance", "legacy", "generations", "multigenerational", "family reunion", "family secrets", "family drama", "dysfunctional", 
                "dysfunctional family", "family conflict", "family relationships", "family values", "family ties", "parent-child relationship", "relationship",
                "coming-of-age", "parenthood", "growing up", "childhood", "teenage years", "aging parents", "grandparents"]

    for i in range(len(synopsis_list)):
        for keyword in keywords:
            if keyword in synopsis_list[i]:
                if i not in match_index_list:
                    match_index_list.append(i)

    return match_index_list

# Call synopses function to put all synopses into list
synopses("https://www.imdb.com/search/title/?title_type=feature&num_votes=25000,&genres=drama&view=simple")
synopses("https://www.imdb.com/search/title/?title_type=feature&num_votes=25000,&genres=drama&view=simple&start=51&ref_=adv_nxt")

# Create Data Frame for Movie information
df_drama_1 = pd.DataFrame(movie_table("https://www.imdb.com/search/title/?title_type=feature&num_votes=25000,&genres=drama&view=simple"), 
                            columns=['Index', 'Title', 'Year', 'Rating'])
df_drama_2 = pd.DataFrame(movie_table("https://www.imdb.com/search/title/?title_type=feature&num_votes=25000,&genres=drama&view=simple&start=51&ref_=adv_nxt"), 
                            columns=['Index', 'Title', 'Year', 'Rating'])
df_drama = pd.concat([df_drama_1, df_drama_2], ignore_index=True).assign(Genre='Drama', Synopsis=synopsis_list)

# Output information of movies that contain family keywords
pd.set_option('display.max_rows', None)
df_drama.iloc[text_search(synopsis_list)]
# Out:
# <ipython-input-1-0d7a4608748b>:122: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/nixoncarino/Desktop/chromedriver')
#    Index                                              Title  Year Rating  \
# 0     1.                                  A Man Called Otto  2022    7.5
# 3     4.                                               Dune  2021      8
# 4     5.                                               Heat  1995    8.3
# 5     6.                           The Shawshank Redemption  1994    9.3
# 6     7.                                  Top Gun: Maverick  2022    8.3
# 7     8.                                      The Godfather  1972    9.2
# 8     9.                                          Book Club  2018    6.1
# 12   13.                                          Midsommar  2019    7.1
# 13   14.                                       Interstellar  2014    8.6
# 17   18.                                         The Batman  2022    7.8
# 18   19.                                  Avengers: Endgame  2019    8.4
# 19   20.                                  American Graffiti  1973    7.4
# 20   21.                                    The Dark Knight  2008      9
# 21   22.                                       Pulp Fiction  1994    8.9
# 23   24.                                  Blade Runner 2049  2017      8
# 25   26.                                            Top Gun  1986    6.9
# 26   27.                                            Titanic  1997    7.9
# 27   28.                                   The Glass Castle  2017    7.1
# 28   29.                            Where the Crawdads Sing  2022    7.2
# 29   30.                                  Pride & Prejudice  2005    7.8
# 30   31.                     Black Panther: Wakanda Forever  2022    6.7
# 31   32.                                             Flight  2012    7.3
# 32   33.                                             Nobody  2021    7.4
# 33   34.                            The Wolf of Wall Street  2013    8.2
# 35   36.                             Léon: The Professional  1994    8.5
# 36   37.                                     The Green Mile  1999    8.6
# 38   39.                               Fifty Shades of Grey  2015    4.2
# 39   40.                      Once Upon a Time in Hollywood  2019    7.6
# 40   41.  The Lord of the Rings: The Fellowship of the Ring  2001    8.8
# 41   42.                                           Parasite  2019    8.5
# 42   43.                                    American Psycho  2000    7.6
# 43   44.                                       The Departed  2006    8.5
# 44   45.                                               1917  2019    8.2
# 45   46.                                        Knock Knock  2015    4.9
# 46   47.                                         Goodfellas  1990    8.7
# 48   49.                                         Hereditary  2018    7.3
# 49   50.                                          Gladiator  2000    8.5
# 50   51.                                         Fight Club  1999    8.8
# 51   52.                                    Black Hawk Down  2001    7.7
# 52   53.                                 Where the Heart Is  2000    6.7
# 53   54.                     All Quiet on the Western Front  2022    7.8
# 54   55.                                           Whiplash  2014    8.5
# 57   58.                                     A Time to Kill  1996    7.5
# 58   59.                                  Good Will Hunting  1997    8.3
# 59   60.                                          Tombstone  1993    7.8
# 60   61.                                          Prisoners  2013    8.1
# 64   65.                               Inglourious Basterds  2009    8.3
# 66   67.                                   Schindler's List  1993      9
# 67   68.                                            Traffic  2000    7.6
# 68   69.                                       Forrest Gump  1994    8.8
# 69   70.                                              Joker  2019    8.4
# 71   72.                             Luther: The Fallen Sun  2023    6.4
# 72   73.                                   Fatal Attraction  1987    6.9
# 73   74.                           The Silence of the Lambs  1991    8.6
# 74   75.                                  American Gangster  2007    7.8
# 75   76.                                        Taxi Driver  1976    8.2
# 76   77.                                      The Outsiders  1983      7
# 77   78.                              The Godfather Part II  1974      9
# 78   79.                                         Black Swan  2010      8
# 79   80.                                         Knives Out  2019    7.9
# 80   81.                                    The Jungle Book  2016    7.4
# 81   82.                                             Oldboy  2003    8.4
# 82   83.                                           Twilight  2008    5.3
# 84   85.                                Requiem for a Dream  2000    8.3
# 85   86.                                              After  2019    5.3
# 86   87.                                The French Dispatch  2021    7.1
# 88   89.                                 The Breakfast Club  1985    7.8
# 89   90.                             No Country for Old Men  2007    8.2
# 90   91.                                      Hacksaw Ridge  2016    8.1
# 91   92.                                              Elvis  2022    7.3
# 92   93.                                           Ad Astra  2019    6.5
# 95   96.                                   Django Unchained  2012    8.4
# 96   97.                                       The Prestige  2006    8.5
# 97   98.                                 The Age of Adaline  2015    7.2
# 98   99.                                             Blonde  2022    5.5
#
#     Genre                                           Synopsis
# 0   Drama  Otto Anderson, a 63-year-old widower, lives in...
# 3   Drama  The story opens with a woman telling a portion...
# 4   Drama  An inbound Los Angeles Blue Line train pulls i...
# 5   Drama  In 1947, Andy Dufresne (Tim Robbins), a banker...
# 6   Drama  More than 30 years after graduating from Top G...
# 7   Drama  In late summer 1945, guests are gathered for t...
# 8   Drama  Diane (Diane Keaton), Vivian (Jane Fonda), Sha...
# 12  Drama  The film opens with a mural of a bizarre, eeri...
# 13  Drama  A group of elderly people are giving interview...
# 17  Drama  On Halloween, Gotham City mayor Don Mitchell J...
# 18  Drama  In the opening, Clint Barton is teaching his d...
# 19  Drama  It's the last night of summer in 1962, and a n...
# 20  Drama  The movie begins with a gang of men with clown...
# 21  Drama  Late one morning in the Hawthorne Grill, a res...
# 23  Drama  The story opens in 2049, thirty years after th...
# 25  Drama  The aircraft carrier USS Enterprise (CVN-65) i...
# 26  Drama  In 1996, treasure hunter Brock Lovett (Bill Pa...
# 27  Drama  As a child, Jeannette Walls lives a nomadic li...
# 28  Drama  A dead body is found and Catherine "Kya" Clark...
# 29  Drama  This film is the story of the Bennet family, a...
# 30  Drama  In 1571, the Yucatán people fell ill to the pl...
# 31  Drama  In the opening scene in a hotel room, Whip Whi...
# 32  Drama  Hutch Mansell (Bob Odenkirk) is a seemingly or...
# 33  Drama  The movie opens with a TV advertisement for St...
# 35  Drama  Léon (Jean Reno) is a hitman (or "cleaner" as ...
# 36  Drama  The movie opens with a group of people running...
# 38  Drama  Anastasia (Ana) Steele is a 22-year-old colleg...
# 39  Drama  The film opens with a clip from an old Western...
# 40  Drama  The prologue, spoken by Galadriel, shows the D...
# 41  Drama  Ki-woo Kim (Choi Woo-Shik) is a young man livi...
# 42  Drama  A white background. Red drops begin to fall pa...
# 43  Drama  In voiceover, Irish-American mobster Frank Cos...
# 44  Drama  On 6 April 1917, aerial reconnaissance has obs...
# 45  Drama  Architect and happily married man Evan Webber ...
# 46  Drama  The film opens with three men driving in their...
# 48  Drama  The story begins with the viewer looking out f...
# 49  Drama  Shouting "Roma victor!" as his forces attack, ...
# 50  Drama  We back out of the webbing of neurons and brai...
# 51  Drama  In early 1990s Somalia, famine and civil war h...
# 52  Drama  Seventeen-year-old, seven-months-pregnant Nova...
# 53  Drama  In Spring 1917, three years into the First Wor...
# 54  Drama  The films opens with Andrew Neimann (Miles Tel...
# 57  Drama  Two white racists, Billy Ray Cobb (Nicky Katt)...
# 58  Drama  Though Will Hunting (Matt Damon) has genius-le...
# 59  Drama  Curly Bill Brocuis (Powers Boothe) and his ban...
# 60  Drama  Keller Dover (Hugh Jackman) and his son Ralph ...
# 64  Drama  Chapter One: "Once Upon a Time..... in Nazi-Oc...
# 66  Drama  The relocation of Polish Jews from surrounding...
# 67  Drama  The film begins in Mexico, where police office...
# 68  Drama  The film begins with a feather falling to the ...
# 69  Drama  The story takes place in Gotham City, 1981.\n\...
# 71  Drama  Wealthy city trader and serial killer David Ro...
# 72  Drama  Dan Gallagher (Michael Douglas) is a successfu...
# 73  Drama  Promising FBI Academy student Clarice Starling...
# 74  Drama  The film opens with Bumpy Johnson (Clarence Wi...
# 75  Drama  Travis Bickle (Robert De Niro) goes to a New Y...
# 76  Drama  The film opens with Ponyboy Curtis (C. Thomas ...
# 77  Drama  The Godfather Part II presents two parallel st...
# 78  Drama  The movie opens as Nina Sayers (Natalie Portma...
# 79  Drama  Wealthy crime novelist Harlan Thrombey invites...
# 80  Drama  The panther Bagheera opens the film by saying ...
# 81  Drama  The film begins in medias res, with the silhou...
# 82  Drama  Seventeen-year-old Bella Swan (Kristen Stewart...
# 84  Drama  Harry Goldfarb (Jared Leto) and Tyrone Love (M...
# 85  Drama  The movie opens with a voice-over by a teenage...
# 86  Drama  The film begins with the narrated obituary of ...
# 88  Drama  The plot follows five students at fictional Sh...
# 89  Drama  The film opens with a shot of desolate, wide-o...
# 90  Drama  In rural 1920s Virginia, the young Desmond Dos...
# 91  Drama  Las Vegas, January 1997.\n\nColonel Tom Parker...
# 92  Drama  In the near future, the Solar System is being ...
# 95  Drama  In 1858, Django (Jamie Foxx), a slave, is chai...
# 96  Drama  The Prestige begins with shots of several doze...
# 97  Drama  Adaline Bowman (Blake Lively) is seen purchasi...
# 98  Drama  As a young girl, Norma Jeane Mortenson grows u...
