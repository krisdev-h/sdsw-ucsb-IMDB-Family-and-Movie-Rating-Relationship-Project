# %%
import requests
from bs4 import BeautifulSoup
from tabulate import tabulate
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By

''' 
This program merges all of the separate programs (protagonists.ipynb and synopsis.ipynb) and adds the text search function. It will
return all of the movies that contain family keywords inside a data frame. This program runs in approximately 7-8 mins."
'''

def movie_table(url):
    webpage = url
    response = requests.get(webpage)

    page = response.text

    soup = BeautifulSoup(page, 'html.parser')
    beautiful_page = soup.get_text()

    ratings = []
    years = []
    titles = []
    movie_nums = []

    lines = beautiful_page.splitlines()

    for line in lines:
        if "(20" in line and ")" in line or '(19' in line and ')' in line:
            years.append(line)

    rep_years = []
    nrep_years = []
    year_indices = []

    for year in years:
        
        if lines.count(year) > 1:
            if year not in rep_years:
                rep_years.append(year)
        if lines.count(year) == 1:
            nrep_years.append(year)

    for i in range(len(rep_years)):
        first_instance = lines.index(rep_years[i])
        year_indices.append(first_instance)

        for j, item in enumerate(lines[first_instance+1:], start=first_instance+1):
            if item == rep_years[i]:
                year_indices.append(j)

    for year in nrep_years:
        if year in lines:
            index = lines.index(year)
            year_indices.append(index)


    for index in sorted(year_indices):
        title = lines[index-1]
        titles.append(title)

        rating = lines[index+6]
        ratings.append(rating)

        movie_num = lines[index-3]
        movie_nums.append(movie_num) 
        

    ratings = [rating.lstrip() for rating in ratings]
    for i in range(len(ratings)):
        if ratings[i] == '':
            ratings[i] = "None"


    for i in range(len(years)):
        for j in range(len(years[i])):
            if years[i][j].isnumeric():
                number_index = years[i].find(years[i][j])
                years[i] = years[i][number_index:number_index+4]
                break


    table_data = list(zip(movie_nums, titles, years, ratings))
    # headers = ["Movie Number", "Title", "Year", "Rating"]

    # print(tabulate(table_data, headers=headers))
    
    return table_data

synopsis_list = []

# Function to get the synopsis from every movie in the webpage
def synopses(link):
    webpage = link
    response = requests.get(webpage)

    page = response.text

    soup = BeautifulSoup(page, 'html.parser')

    url_list = []
    movie_url_list = []
    movie_ref_nums = []

    # Get all the hyperlinks
    for link in soup.find_all('a'):
        url_list.append(link.get('href'))

    # Filter to get movie title hyperlinks
    for url in url_list:
        if '/title/tt' in url:
            if url not in movie_url_list:
                movie_url_list.append(url) 

    # Take the reference number from the movie url
    for movie_url in movie_url_list:
        movie_ref_nums.append(movie_url[7:16])


    # Extract the synopsis from every movie then append to a list
    driver = webdriver.Chrome('/Users/nixoncarino/Desktop/chromedriver')

    for i in movie_ref_nums:
        url = "https://www.imdb.com/title/" + i + "/plotsummary/?ref_=tt_stry_pl#synopsis"
        try:
            driver.get(url)
            synopsis_element = driver.find_element(By.XPATH, '//*[@id="__next"]/main/div/section/div/section/div/div[1]/section[2]/div[2]/ul/li/div/div/div/div/div')
        except:
            synopsis_list.append("No Synopsis")
        else:
            synopsis = synopsis_element.text
            synopsis_list.append(synopsis)

# Function that find family related words on the synopsis
def text_search(synopsis_list):
    # The indices of the synopses that contain any of the keywords
    match_index_list = []

    keywords = ["family", "parenting", "father", "mother", "son", "daughter", "sibling", "brother", "sister", "marriage", "divorce", "blended family", "adoption",
                "foster care", "custody", "inheritance", "legacy", "generations", "multigenerational", "family reunion", "family secrets", "family drama", "dysfunctional", 
                "dysfunctional family", "family conflict", "family relationships", "family values", "family ties", "parent-child relationship", "relationship",
                "coming-of-age", "parenthood", "growing up", "childhood", "teenage years", "aging parents", "grandparents"]

    for i in range(len(synopsis_list)):
        for keyword in keywords:
            if keyword in synopsis_list[i]:
                if i not in match_index_list:
                    match_index_list.append(i)

    return match_index_list

# Call synopses function to put all synopses into list
synopses("https://www.imdb.com/search/title/?title_type=feature&num_votes=25000,&genres=drama&view=simple")
synopses("https://www.imdb.com/search/title/?title_type=feature&num_votes=25000,&genres=drama&view=simple&start=51&ref_=adv_nxt")

# Create Data Frame for Movie information
df_drama_1 = pd.DataFrame(movie_table("https://www.imdb.com/search/title/?title_type=feature&num_votes=25000,&genres=adventure&view=simple"), 
                            columns=['Index', 'Title', 'Year', 'Rating'])
df_drama_2 = pd.DataFrame(movie_table("https://www.imdb.com/search/title/?title_type=feature&num_votes=25000,&genres=adventure&view=simple&start=51&ref_=adv_nxt"), 
                            columns=['Index', 'Title', 'Year', 'Rating'])
df_drama = pd.concat([df_drama_1, df_drama_2], ignore_index=True).assign(Genre='Adventure', Synopsis=synopsis_list)

# Output information of movies that contain family keywords
pd.set_option('display.max_rows', None)
df_drama.iloc[text_search(synopsis_list)]
# Out:
# <ipython-input-2-e22bf9a63f03>:122: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/nixoncarino/Desktop/chromedriver')
#    Index                                              Title  Year Rating  \
# 0     1.                     Guardians of the Galaxy Vol. 3  2023    8.3
# 3     4.                            Guardians of the Galaxy  2014      8
# 4     5.                                            Ghosted  2023    5.8
# 5     6.                     Guardians of the Galaxy Vol. 2  2017    7.6
# 6     7.                  Ant-Man and the Wasp: Quantumania  2023    6.2
# 7     8.                                               Dune  2021      8
# 8     9.                           Avatar: The Way of Water  2022    7.7
# 12   13.                                       Interstellar  2014    8.6
# 13   14.                                                 65  2023    5.4
# 17   18.                            Spider-Man: No Way Home  2021    8.2
# 18   19.                                          Peter Pan  2003    6.8
# 19   20.                                          Inception  2010    8.8
# 20   21.              Harry Potter and the Sorcerer's Stone  2001    7.6
# 21   22.                                Conan the Barbarian  1982    6.9
# 23   24.                     Black Panther: Wakanda Forever  2022    6.7
# 25   26.  The Lord of the Rings: The Fellowship of the Ring  2001    8.8
# 26   27.                  Spider-Man: Into the Spider-Verse  2018    8.4
# 27   28.                             Avengers: Infinity War  2018    8.4
# 28   29.                                          Idiocracy  2006    6.5
# 29   30.                                          Gladiator  2000    8.5
# 30   31.                                              Plane  2023    6.5
# 31   32.                       Kingsman: The Secret Service  2014    7.7
# 32   33.                                        The Goonies  1985    7.7
# 33   34.          Star Wars: Episode I - The Phantom Menace  1999    6.5
# 35   36.                                  Starship Troopers  1997    7.3
# 36   37.                               Inglourious Basterds  2009    8.3
# 38   39.                                        Escape Room  2019    6.4
# 39   40.                                 Back to the Future  1985    8.5
# 40   41.                                      Jurassic Park  1993    8.2
# 41   42.                                               Dune  1984    6.3
# 42   43.               Escape Room: Tournament of Champions  2021    5.7
# 43   44.                           The Grand Budapest Hotel  2014    8.1
# 44   45.                                         Spider-Man  2002    7.4
# 45   46.                             Spider-Man: Homecoming  2017    7.4
# 46   47.         Star Wars: Episode VI - Return of the Jedi  1983    8.3
# 48   49.                                             Avatar  2009    7.9
# 49   50.                                  The Fifth Element  1997    7.6
# 50   51.                                     No Time to Die  2021    7.3
# 51   52.                                    The Jungle Book  2016    7.4
# 52   53.        Doctor Strange in the Multiverse of Madness  2022    6.9
# 53   54.                           Jurassic World: Dominion  2022    5.6
# 54   55.                                           Eternals  2021    6.3
# 57   58.                                  Super Mario Bros.  1993    4.1
# 58   59.                                         Boss Level  2020    6.8
# 59   60.                                           Ad Astra  2019    6.5
# 60   61.                                     The King's Man  2021    6.3
# 64   65.      Indiana Jones and the Raiders of the Lost Ark  1981    8.4
# 66   67.                                 The Princess Bride  1987      8
# 67   68.                                            Tangled  2010    7.7
# 68   69.                                               Jaws  1975    8.1
# 69   70.                                             Sing 2  2021    7.4
# 71   72.                              The Magnificent Seven  2016    6.8
# 72   73.                                          Uncharted  2022    6.3
# 73   74.                                      Almost Famous  2000    7.9
# 74   75.                        Kingsman: The Golden Circle  2017    6.7
# 75   76.         Star Wars: Episode VII - The Force Awakens  2015    7.8
# 76   77.                                       Tomorrowland  2015    6.4
# 77   78.                                 The Little Mermaid  1989    7.6
# 78   79.                                   The Tomorrow War  2021    6.5
# 79   80.                                       Galaxy Quest  1999    7.4
# 80   81.      The Lord of the Rings: The Return of the King  2003      9
# 81   82.                                        Stand by Me  1986    8.1
# 82   83.                                     Knight and Day  2010    6.3
# 84   85.     Star Wars: Episode V - The Empire Strikes Back  1980    8.7
# 85   86.                 Captain America: The First Avenger  2011    6.9
# 86   87.                    The Hunger Games: Catching Fire  2013    7.5
# 88   89.                                           Free Guy  2021    7.1
# 89   90.                                            Shazam!  2019      7
# 90   91.                                      The Lion King  1994    8.5
# 91   92.       Star Wars: Episode II - Attack of the Clones  2002    6.6
# 92   93.                                      Spirited Away  2001    8.6
# 95   96.                                      Suicide Squad  2016    5.9
# 96   97.                             Mechanic: Resurrection  2016    5.7
# 97   98.                                         Prometheus  2012      7
# 98   99.                                          Spartacus  1960    7.9
#
#         Genre                                           Synopsis
# 0   Adventure  Otto Anderson, a 63-year-old widower, lives in...
# 3   Adventure  The story opens with a woman telling a portion...
# 4   Adventure  An inbound Los Angeles Blue Line train pulls i...
# 5   Adventure  In 1947, Andy Dufresne (Tim Robbins), a banker...
# 6   Adventure  More than 30 years after graduating from Top G...
# 7   Adventure  In late summer 1945, guests are gathered for t...
# 8   Adventure  Diane (Diane Keaton), Vivian (Jane Fonda), Sha...
# 12  Adventure  The film opens with a mural of a bizarre, eeri...
# 13  Adventure  A group of elderly people are giving interview...
# 17  Adventure  On Halloween, Gotham City mayor Don Mitchell J...
# 18  Adventure  In the opening, Clint Barton is teaching his d...
# 19  Adventure  It's the last night of summer in 1962, and a n...
# 20  Adventure  The movie begins with a gang of men with clown...
# 21  Adventure  Late one morning in the Hawthorne Grill, a res...
# 23  Adventure  The story opens in 2049, thirty years after th...
# 25  Adventure  The aircraft carrier USS Enterprise (CVN-65) i...
# 26  Adventure  In 1996, treasure hunter Brock Lovett (Bill Pa...
# 27  Adventure  As a child, Jeannette Walls lives a nomadic li...
# 28  Adventure  A dead body is found and Catherine "Kya" Clark...
# 29  Adventure  This film is the story of the Bennet family, a...
# 30  Adventure  In 1571, the Yucatán people fell ill to the pl...
# 31  Adventure  In the opening scene in a hotel room, Whip Whi...
# 32  Adventure  Hutch Mansell (Bob Odenkirk) is a seemingly or...
# 33  Adventure  The movie opens with a TV advertisement for St...
# 35  Adventure  Léon (Jean Reno) is a hitman (or "cleaner" as ...
# 36  Adventure  The movie opens with a group of people running...
# 38  Adventure  Anastasia (Ana) Steele is a 22-year-old colleg...
# 39  Adventure  The film opens with a clip from an old Western...
# 40  Adventure  The prologue, spoken by Galadriel, shows the D...
# 41  Adventure  Ki-woo Kim (Choi Woo-Shik) is a young man livi...
# 42  Adventure  A white background. Red drops begin to fall pa...
# 43  Adventure  In voiceover, Irish-American mobster Frank Cos...
# 44  Adventure  On 6 April 1917, aerial reconnaissance has obs...
# 45  Adventure  Architect and happily married man Evan Webber ...
# 46  Adventure  The film opens with three men driving in their...
# 48  Adventure  The story begins with the viewer looking out f...
# 49  Adventure  Shouting "Roma victor!" as his forces attack, ...
# 50  Adventure  We back out of the webbing of neurons and brai...
# 51  Adventure  In early 1990s Somalia, famine and civil war h...
# 52  Adventure  Seventeen-year-old, seven-months-pregnant Nova...
# 53  Adventure  In Spring 1917, three years into the First Wor...
# 54  Adventure  The films opens with Andrew Neimann (Miles Tel...
# 57  Adventure  Two white racists, Billy Ray Cobb (Nicky Katt)...
# 58  Adventure  Though Will Hunting (Matt Damon) has genius-le...
# 59  Adventure  Curly Bill Brocuis (Powers Boothe) and his ban...
# 60  Adventure  Keller Dover (Hugh Jackman) and his son Ralph ...
# 64  Adventure  Chapter One: "Once Upon a Time..... in Nazi-Oc...
# 66  Adventure  The relocation of Polish Jews from surrounding...
# 67  Adventure  The film begins in Mexico, where police office...
# 68  Adventure  The film begins with a feather falling to the ...
# 69  Adventure  The story takes place in Gotham City, 1981.\n\...
# 71  Adventure  Wealthy city trader and serial killer David Ro...
# 72  Adventure  Dan Gallagher (Michael Douglas) is a successfu...
# 73  Adventure  Promising FBI Academy student Clarice Starling...
# 74  Adventure  The film opens with Bumpy Johnson (Clarence Wi...
# 75  Adventure  Travis Bickle (Robert De Niro) goes to a New Y...
# 76  Adventure  The film opens with Ponyboy Curtis (C. Thomas ...
# 77  Adventure  The Godfather Part II presents two parallel st...
# 78  Adventure  The movie opens as Nina Sayers (Natalie Portma...
# 79  Adventure  Wealthy crime novelist Harlan Thrombey invites...
# 80  Adventure  The panther Bagheera opens the film by saying ...
# 81  Adventure  The film begins in medias res, with the silhou...
# 82  Adventure  Seventeen-year-old Bella Swan (Kristen Stewart...
# 84  Adventure  Harry Goldfarb (Jared Leto) and Tyrone Love (M...
# 85  Adventure  The movie opens with a voice-over by a teenage...
# 86  Adventure  The film begins with the narrated obituary of ...
# 88  Adventure  The plot follows five students at fictional Sh...
# 89  Adventure  The film opens with a shot of desolate, wide-o...
# 90  Adventure  In rural 1920s Virginia, the young Desmond Dos...
# 91  Adventure  Las Vegas, January 1997.\n\nColonel Tom Parker...
# 92  Adventure  In the near future, the Solar System is being ...
# 95  Adventure  In 1858, Django (Jamie Foxx), a slave, is chai...
# 96  Adventure  The Prestige begins with shots of several doze...
# 97  Adventure  Adaline Bowman (Blake Lively) is seen purchasi...
# 98  Adventure  As a young girl, Norma Jeane Mortenson grows u...
