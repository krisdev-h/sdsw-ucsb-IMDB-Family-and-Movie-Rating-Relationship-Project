# %%
# FULL ANIMATION DATA FRAME

# %%
import requests
from bs4 import BeautifulSoup
from tabulate import tabulate
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By

''' 
This program merges all of the separate programs (protagonists.ipynb and synopsis.ipynb) and adds the text search function. It will
return all of the movies that contain family keywords inside a data frame. This program runs in approximately 7-8 mins."
'''

def movie_table(url):
    webpage = url
    response = requests.get(webpage)

    page = response.text

    soup = BeautifulSoup(page, 'html.parser')
    beautiful_page = soup.get_text()

    ratings = []
    years = []
    titles = []
    movie_nums = []

    lines = beautiful_page.splitlines()

    for line in lines:
        if "(20" in line and ")" in line or '(19' in line and ')' in line:
            years.append(line)

    rep_years = []
    nrep_years = []
    year_indices = []

    for year in years:
        
        if lines.count(year) > 1:
            if year not in rep_years:
                rep_years.append(year)
        if lines.count(year) == 1:
            nrep_years.append(year)

    for i in range(len(rep_years)):
        first_instance = lines.index(rep_years[i])
        year_indices.append(first_instance)

        for j, item in enumerate(lines[first_instance+1:], start=first_instance+1):
            if item == rep_years[i]:
                year_indices.append(j)

    for year in nrep_years:
        if year in lines:
            index = lines.index(year)
            year_indices.append(index)


    for index in sorted(year_indices):
        title = lines[index-1]
        titles.append(title)

        rating = lines[index+6]
        ratings.append(rating)

        movie_num = lines[index-3]
        movie_nums.append(movie_num) 
        

    ratings = [rating.lstrip() for rating in ratings]
    for i in range(len(ratings)):
        if ratings[i] == '':
            ratings[i] = "None"


    for i in range(len(years)):
        for j in range(len(years[i])):
            if years[i][j].isnumeric():
                number_index = years[i].find(years[i][j])
                years[i] = years[i][number_index:number_index+4]
                break


    table_data = list(zip(movie_nums, titles, years, ratings))
    # headers = ["Movie Number", "Title", "Year", "Rating"]

    # print(tabulate(table_data, headers=headers))
    
    return table_data

synopsis_list = []

# Function to get the synopsis from every movie in the webpage
def synopses(link):
    webpage = link
    response = requests.get(webpage)

    page = response.text

    soup = BeautifulSoup(page, 'html.parser')

    url_list = []
    movie_url_list = []
    movie_ref_nums = []

    # Get all the hyperlinks
    for link in soup.find_all('a'):
        url_list.append(link.get('href'))

    # Filter to get movie title hyperlinks
    for url in url_list:
        if '/title/tt' in url:
            if url not in movie_url_list:
                movie_url_list.append(url) 

    # Take the reference number from the movie url
    for movie_url in movie_url_list:
        movie_ref_nums.append(movie_url[7:16])


    # Extract the synopsis from every movie then append to a list
    driver = webdriver.Chrome('/Users/nixoncarino/Desktop/chromedriver')

    for i in movie_ref_nums:
        url = "https://www.imdb.com/title/" + i + "/plotsummary/?ref_=tt_stry_pl#synopsis"
        try:
            driver.get(url)
            synopsis_element = driver.find_element(By.XPATH, '//*[@id="__next"]/main/div/section/div/section/div/div[1]/section[2]/div[2]/ul/li/div/div/div/div/div')
        except:
            synopsis_list.append("No Synopsis")
        else:
            synopsis = synopsis_element.text
            synopsis_list.append(synopsis)

# Function that find family related words on the synopsis
def text_search(synopsis_list):
    # The indices of the synopses that contain any of the keywords
    match_index_list = []

    keywords = ["family", "parenting", "father", "mother", "son", "daughter", "sibling", "brother", "sister", "marriage", "divorce", "blended family", "adoption",
                "foster care", "custody", "inheritance", "legacy", "generations", "multigenerational", "family reunion", "family secrets", "family drama", "dysfunctional", 
                "dysfunctional family", "family conflict", "family relationships", "family values", "family ties", "parent-child relationship", "relationship",
                "coming-of-age", "parenthood", "growing up", "childhood", "teenage years", "aging parents", "grandparents"]

    for i in range(len(synopsis_list)):
        for keyword in keywords:
            if keyword in synopsis_list[i]:
                if i not in match_index_list:
                    match_index_list.append(i)

    return match_index_list

# Call synopses function to put all synopses into list
synopses("https://www.imdb.com/search/title/?title_type=feature&genres=animation&view=simple&ref_=adv_prv")
synopses("https://www.imdb.com/search/title/?title_type=feature&genres=animation&view=simple&start=51&ref_=adv_nxt")

# Create Data Frame for Movie information
df_animation_1 = pd.DataFrame(movie_table("https://www.imdb.com/search/title/?title_type=feature&genres=animation&view=simple&ref_=adv_prv"), 
                            columns=['Index', 'Title', 'Year', 'Rating'])
df_animation_2 = pd.DataFrame(movie_table("https://www.imdb.com/search/title/?title_type=feature&genres=animation&view=simple&start=51&ref_=adv_nxt"), 
                            columns=['Index', 'Title', 'Year', 'Rating'])
df_animation = pd.concat([df_animation_1, df_animation_2], ignore_index=True).assign(Genre='Animation', Synopsis=synopsis_list)
# Out:
# /var/folders/dr/q8lk9535757d9krftyrx8kgc0000gn/T/ipykernel_18567/3687358221.py:122: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/nixoncarino/Desktop/chromedriver')

# %%
# Output information of movies that contain family keywords
pd.set_option('display.max_rows', None)
animation_full_data = df_animation.iloc[text_search(synopsis_list)]
animation_full_data
# Out:
#    Index                                       Title  Year Rating      Genre  \
# 0     1.                 The Super Mario Bros. Movie  2023    7.3  Animation
# 4     5.                                  Your Name.  2016    8.4  Animation
# 6     7.           Spider-Man: Into the Spider-Verse  2018    8.4  Animation
# 7     8.                                      Sing 2  2021    7.4  Animation
# 8     9.                                     Encanto  2021    7.2  Animation
# 10   11.                               Spirited Away  2001    8.6  Animation
# 11   12.                                       Moana  2016    7.6  Animation
# 12   13.                               The Lion King  1994    8.5  Animation
# 13   14.                               Lilo & Stitch  2002    7.3  Animation
# 16   17.              Guillermo del Toro's Pinocchio  2022    7.6  Animation
# 17   18.                                        Cars  2006    7.2  Animation
# 18   19.                                    Zootopia  2016      8  Animation
# 19   20.                               The Lion King  2019    6.8  Animation
# 20   21.                                 Ratatouille  2007    8.1  Animation
# 21   22.                    How to Train Your Dragon  2010    8.1  Animation
# 22   23.                                       Shrek  2001    7.9  Animation
# 25   26.                        Howl's Moving Castle  2004    8.2  Animation
# 26   27.                                   Toy Story  1995    8.3  Animation
# 27   28.                              Over the Hedge  2006    6.7  Animation
# 28   29.                           Fantastic Mr. Fox  2009    7.9  Animation
# 29   30.                                The Bad Guys  2022    6.8  Animation
# 30   31.                                Finding Nemo  2003    8.2  Animation
# 32   33.                                   The Lorax  2012    6.4  Animation
# 33   34.                                  Inside Out  2015    8.1  Animation
# 34   35.                                      Frozen  2013    7.4  Animation
# 36   37.                               Puss in Boots  2011    6.6  Animation
# 37   38.                                  Shark Tale  2004      6  Animation
# 38   39.                                        Coco  2017    8.4  Animation
# 40   41.                                          Up  2009    8.3  Animation
# 41   42.                                      WALL·E  2008    8.4  Animation
# 43   44.                    Minions: The Rise of Gru  2022    6.5  Animation
# 44   45.                              The Lego Movie  2014    7.7  Animation
# 45   46.                                        Sing  2016    7.1  Animation
# 46   47.                                    Coraline  2009    7.7  Animation
# 47   48.                                    Hercules  1997    7.3  Animation
# 48   49.                                     Tangled  2010    7.7  Animation
# 49   50.                      Grave of the Fireflies  1988    8.5  Animation
# 50   51.                                A Bug's Life  1998    7.2  Animation
# 51   52.                              Monsters, Inc.  2001    8.1  Animation
# 52   53.                                         Rio  2011    6.9  Animation
# 53   54.                          Hotel Transylvania  2012      7  Animation
# 54   55.                          The Little Mermaid  1989    7.6  Animation
# 55   56.                                 Turning Red  2022      7  Animation
# 56   57.                                     Shrek 2  2004    7.3  Animation
# 57   58.                                     Aladdin  1992      8  Animation
# 59   60.                         The Prince of Egypt  1998    7.2  Animation
# 60   61.                               Kung Fu Panda  2008    7.6  Animation
# 62   63.                                        Home  2015    6.5  Animation
# 63   64.                                     Ice Age  2002    7.5  Animation
# 64   65.                               Incredibles 2  2018    7.6  Animation
# 66   67.                                      Trolls  2016    6.4  Animation
# 68   69.                        Beauty and the Beast  1991      8  Animation
# 69   70.  How to Train Your Dragon: The Hidden World  2019    7.4  Animation
# 72   73.                                        Soul  2020      8  Animation
# 73   74.                                 Toy Story 4  2019    7.7  Animation
# 75   76.                                  Madagascar  2005    6.9  Animation
# 76   77.                                       Mulan  1998    7.6  Animation
# 78   79.                           Princess Mononoke  1997    8.3  Animation
# 79   80.                                   Frozen II  2019    6.8  Animation
# 80   81.                                 Toy Story 3  2010    8.3  Animation
# 82   83.                   Atlantis: The Lost Empire  2001    6.9  Animation
# 83   84.                     Who Framed Roger Rabbit  1988    7.7  Animation
# 84   85.                                       Rango  2011    7.2  Animation
# 85   86.                               Despicable Me  2010    7.6  Animation
# 86   87.                   The Princess and the Frog  2009    7.1  Animation
# 87   88.                    Raya and the Last Dragon  2021    7.3  Animation
# 88   89.                              Wreck-It Ralph  2012    7.7  Animation
# 89   90.                          My Neighbor Totoro  1988    8.1  Animation
# 90   91.                    The Emperor's New Groove  2000    7.4  Animation
# 91   92.                               Sausage Party  2016    6.1  Animation
# 93   94.                             Treasure Planet  2002    7.2  Animation
# 96   97.                           The Good Dinosaur  2015    6.7  Animation
# 97   98.                                   Enchanted  2007    7.1  Animation
# 98   99.                                       Akira  1988      8  Animation
# 99  100.                                      Robots  2005    6.4  Animation
#
#                                              Synopsis
# 0   Italian-American brothers Mario and Luigi have...
# 4   &#12302;&#21531;&#12398;&#21517;&#12399;&#1229...
# 6   This animated film starts with Peter Parker (v...
# 7   Some time after the events of the first film, ...
# 8   While escaping her home from armed conflict, a...
# 10  Ten-year-old Chihiro (voice: Daveigh Chase in ...
# 11  Using a tapa cloth to animate her story, Gramm...
# 12  The Lion King takes place in the Pride Lands o...
# 13  Somewhere on a distant planet, a court is call...
# 16  In Italy during the the Great War, the carpent...
# 17  The movie begins with two announcers, Bob Cutl...
# 18  In the town of Bunnyburrow, 9 year old bunny, ...
# 19  The sun rises over the Pride Lands. Animals fr...
# 20  The movie opens with a TV documentary featurin...
# 21  A Viking boy called Hiccup (voice: Jay Baruche...
# 22  A Scottish man (voiced by Mike Myers) reads a ...
# 25  Over a quaint area of land, shrouded by fog, a...
# 26  A boy called Andy Davis (voice: John Morris) u...
# 27  Spring has arrived and an array of creatures s...
# 28  "Boggis and Bunce and Bean One short, one fat,...
# 29  In Los Angeles, California, in a world of huma...
# 30  Two clownfish, Marlin (Albert Brooks) and his ...
# 32  Ted Wiggins (Zac Efron), an idealistic 12-year...
# 33  Riley is a girl born in Minnesota. Five emotio...
# 34  The Walt Disney Pictures logo and the movie ti...
# 36  Sometime before Puss (Antonio Banderas) meets ...
# 37  Oscar (Will Smith-voice) is a little fish work...
# 38  In Santa Cecilia, Mexico, Imelda Rivera was th...
# 40  Young Carl Fredricksen (Jeremy Leary), a quiet...
# 41  A Dystopia in the Future\n\nApproximately seve...
# 43  The year 1976 is where the story begins. Belle...
# 44  The wizard Vitruvius attempts to protect the "...
# 45  Set in an animated world controlled by animals...
# 46  As the credits appear, a pair of metallic hand...
# 47  Based on both the legend of Hercules and Herac...
# 48  The film opens on a Wanted poster for Flynn Ri...
# 49  &#12302;&#28779;&#22402;&#12427;&#12398;&#2267...
# 50  On a small island with a large tree, a colony ...
# 51  The city of Monstropolis in a world entirely p...
# 52  In Rio de Janeiro, Brazil, birds sing and danc...
# 53  Dracula (voiced by Adam Sandler) is the owner ...
# 54  Ariel, a sixteen-year-old mermaid princess, is...
# 55  In 2002, Meilin "Mei" Lee is a 13-year-old Chi...
# 56  When Shrek and Fiona come back from their hone...
# 57  A street peddler (Robin Williams) is guiding t...
# 59  In Ancient Egypt, Hebrew slaves are hard at wo...
# 60  "Legend tells of a legendary warrior whose kun...
# 62  The alien race known as the Boov are very good...
# 63  20,000 years ago, a grumpy mammoth named Manfr...
# 64  Agent Rick Dicker (Jonathan Banks) is intervie...
# 66  Once upon a time, the Trolls all lived in a tr...
# 68  In the prologue, told through stained glass wi...
# 69  The film opens on a dragon trapper ship. Hiccu...
# 72  Joe Gardner, a middle school music teacher, fe...
# 73  Nine years ago, between the events of the seco...
# 75  At New York City's Central Park Zoo, Marty the...
# 76  During the Han Dynasty in ancient China, the l...
# 78  The tale of Princess Mononoke is a fantasy adv...
# 79  The film opens with young Anna (voice of Hadle...
# 80  Andy Davis (voice: John Morris) is 17 years ol...
# 82  Milo James Thatch is a bright young man, who i...
# 83  Former toon Private Eye Eddie Valiant (Bob Hos...
# 84  In the back of a small car, in a small aquariu...
# 85  The film begins with the news revealing that a...
# 86  In New Orleans, a young girl named Tiana ( Eli...
# 87  500 years prior, Kumandra was a prosperous lan...
# 88  Wreck-It Ralph (voice of John C. Reilly) longs...
# 89  On a warm, sunny day, 10-year-old Satsuki (Eng...
# 90  Vain, pampered and spoiled rich Emperor Kuzco ...
# 91  The film opens at the supermarket Shopwell's o...
# 93  The film opens in a narrative (Tony Jay) which...
# 96  65 million years ago, an asteroid made its way...
# 97  The movie begins with a narration (Julie Andre...
# 98  On July 16, 1988 an atom bomb vaporizes Tokyo....
# 99  In a world of robots, the Copperbottom family ...

# %%
# FULL ADVENTURE DATA FRAME

# %%
import requests
from bs4 import BeautifulSoup
from tabulate import tabulate
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By

def movie_table_2(url):
    webpage = url
    response = requests.get(webpage)

    page = response.text

    soup = BeautifulSoup(page, 'html.parser')
    beautiful_page = soup.get_text()

    ratings = []
    years = []
    titles = []
    movie_nums = []

    lines = beautiful_page.splitlines()

    for line in lines:
        if "(20" in line and ")" in line or '(19' in line and ')' in line:
            years.append(line)

    rep_years = []
    nrep_years = []
    year_indices = []

    for year in years:
        
        if lines.count(year) > 1:
            if year not in rep_years:
                rep_years.append(year)
        if lines.count(year) == 1:
            nrep_years.append(year)

    for i in range(len(rep_years)):
        first_instance = lines.index(rep_years[i])
        year_indices.append(first_instance)

        for j, item in enumerate(lines[first_instance+1:], start=first_instance+1):
            if item == rep_years[i]:
                year_indices.append(j)

    for year in nrep_years:
        if year in lines:
            index = lines.index(year)
            year_indices.append(index)


    for index in sorted(year_indices):
        title = lines[index-1]
        titles.append(title)

        rating = lines[index+6]
        ratings.append(rating)

        movie_num = lines[index-3]
        movie_nums.append(movie_num) 
        

    ratings = [rating.lstrip() for rating in ratings]
    for i in range(len(ratings)):
        if ratings[i] == '':
            ratings[i] = "None"


    for i in range(len(years)):
        for j in range(len(years[i])):
            if years[i][j].isnumeric():
                number_index = years[i].find(years[i][j])
                years[i] = years[i][number_index:number_index+4]
                break


    table_data = list(zip(movie_nums, titles, years, ratings))
    # headers = ["Movie Number", "Title", "Year", "Rating"]

    # print(tabulate(table_data, headers=headers))
    
    return table_data

synopsis_list_2 = []

# Function to get the synopsis from every movie in the webpage
def synopses_2(link):
    webpage = link
    response = requests.get(webpage)

    page = response.text

    soup = BeautifulSoup(page, 'html.parser')

    url_list = []
    movie_url_list = []
    movie_ref_nums = []

    # Get all the hyperlinks
    for link in soup.find_all('a'):
        url_list.append(link.get('href'))

    # Filter to get movie title hyperlinks
    for url in url_list:
        if '/title/tt' in url:
            if url not in movie_url_list:
                movie_url_list.append(url) 

    # Take the reference number from the movie url
    for movie_url in movie_url_list:
        movie_ref_nums.append(movie_url[7:16])


    # Extract the synopsis from every movie then append to a list
    driver = webdriver.Chrome('/Users/nixoncarino/Desktop/chromedriver')

    for i in movie_ref_nums:
        url = "https://www.imdb.com/title/" + i + "/plotsummary/?ref_=tt_stry_pl#synopsis"
        try:
            driver.get(url)
            synopsis_element = driver.find_element(By.XPATH, '//*[@id="__next"]/main/div/section/div/section/div/div[1]/section[2]/div[2]/ul/li/div/div/div/div/div')
        except:
            synopsis_list_2.append("No Synopsis")
        else:
            synopsis = synopsis_element.text
            synopsis_list_2.append(synopsis)

# Function that find family related words on the synopsis
def text_search_2(synopsis_list_2):
    # The indices of the synopses that contain any of the keywords
    match_index_list = []

    keywords = ["family", "parenting", "father", "mother", "son", "daughter", "sibling", "brother", "sister", "marriage", "divorce", "blended family", "adoption",
                "foster care", "custody", "inheritance", "legacy", "generations", "multigenerational", "family reunion", "family secrets", "family drama", "dysfunctional", 
                "dysfunctional family", "family conflict", "family relationships", "family values", "family ties", "parent-child relationship", "relationship",
                "coming-of-age", "parenthood", "growing up", "childhood", "teenage years", "aging parents", "grandparents"]

    for i in range(len(synopsis_list_2)):
        for keyword in keywords:
            if keyword in synopsis_list_2[i]:
                if i not in match_index_list:
                    match_index_list.append(i)

    return match_index_list



# Call synopses function to put all synopses into list
synopses_2("https://www.imdb.com/search/title/?title_type=feature&genres=adventure&view=simple&ref_=adv_prv%22")
synopses_2("https://www.imdb.com/search/title/?title_type=feature&genres=adventure&view=simple&start=51&ref_=adv_nxt")

# Create Data Frame for Movie information
df_adventure_1 = pd.DataFrame(movie_table_2("https://www.imdb.com/search/title/?title_type=feature&genres=adventure&view=simple&ref_=adv_prv%22"), 
                            columns=['Index', 'Title', 'Year', 'Rating'])
df_adventure_2 = pd.DataFrame(movie_table_2("https://www.imdb.com/search/title/?title_type=feature&genres=adventure&view=simple&start=51&ref_=adv_nxt"), 
                            columns=['Index', 'Title', 'Year', 'Rating'])
df_adventure = pd.concat([df_adventure_1, df_adventure_2], ignore_index=True).assign(Genre='Adventure', Synopsis=synopsis_list_2)
# Out:
# /var/folders/dr/q8lk9535757d9krftyrx8kgc0000gn/T/ipykernel_20773/1573796471.py:117: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/nixoncarino/Desktop/chromedriver')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/dr/q8lk9535757d9krftyrx8kgc0000gn/T/ipykernel_20773/1573796471.py in <module>
#     157 df_adventure_2 = pd.DataFrame(movie_table_2("https://www.imdb.com/search/title/?title_type=feature&genres=adventure&view=simple&start=51&ref_=adv_nxt"),
#     158                             columns=['Index', 'Title', 'Year', 'Rating'])
# --> 159 df_adventure = pd.concat([df_adventure_1, df_adventure_2], ignore_index=True).assign(Genre='Adventure', Synopsis=synopsis_list_2)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in assign(self, **kwargs)
#    4504
#    4505         for k, v in kwargs.items():
# -> 4506             data[k] = com.apply_if_callable(v, data)
#    4507         return data
#    4508
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3653         else:
#    3654             # set column
# -> 3655             self._set_item(key, value)
#    3656
#    3657     def _setitem_slice(self, key: slice, value):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3830         ensure homogeneity.
#    3831         """
# -> 3832         value = self._sanitize_column(value)
#    3833
#    3834         if (
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4527
#    4528         if is_list_like(value):
# -> 4529             com.require_length_match(value, self.index)
#    4530         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4531
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/common.py in require_length_match(data, index)
#     555     """
#     556     if len(data) != len(index):
# --> 557         raise ValueError(
#     558             "Length of values "
#     559             f"({len(data)}) "
#
# ValueError: Length of values (100) does not match length of index (99)

# %%
# Output information of movies that contain family keywords
pd.set_option('display.max_rows', None)
adventure_full_data = df_adventure.iloc[text_search(synopsis_list_2)]
animation_full_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/dr/q8lk9535757d9krftyrx8kgc0000gn/T/ipykernel_20773/2288678628.py in <module>
#       1 # Output information of movies that contain family keywords
#       2 pd.set_option('display.max_rows', None)
# ----> 3 adventure_full_data = df_adventure.iloc[text_search(synopsis_list_2)]
#       4 animation_full_data
#
# NameError: name 'df_adventure' is not defined
