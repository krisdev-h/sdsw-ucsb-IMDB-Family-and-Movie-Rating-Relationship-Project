# %%
import requests
from bs4 import BeautifulSoup
from tabulate import tabulate
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By

''' 
This program merges all of the separate programs (protagonists.ipynb and synopsis.ipynb) and adds the text search function. It will
return all of the movies that contain family keywords inside a data frame. This program runs in approximately 7-8 mins."
'''

def movie_table(url):
    webpage = url
    response = requests.get(webpage)

    page = response.text

    soup = BeautifulSoup(page, 'html.parser')
    beautiful_page = soup.get_text()

    ratings = []
    years = []
    titles = []
    movie_nums = []

    lines = beautiful_page.splitlines()

    for line in lines:
        if "(20" in line and ")" in line or '(19' in line and ')' in line:
            years.append(line)

    rep_years = []
    nrep_years = []
    year_indices = []

    for year in years:
        
        if lines.count(year) > 1:
            if year not in rep_years:
                rep_years.append(year)
        if lines.count(year) == 1:
            nrep_years.append(year)

    for i in range(len(rep_years)):
        first_instance = lines.index(rep_years[i])
        year_indices.append(first_instance)

        for j, item in enumerate(lines[first_instance+1:], start=first_instance+1):
            if item == rep_years[i]:
                year_indices.append(j)

    for year in nrep_years:
        if year in lines:
            index = lines.index(year)
            year_indices.append(index)


    for index in sorted(year_indices):
        title = lines[index-1]
        titles.append(title)

        rating = lines[index+6]
        ratings.append(rating)

        movie_num = lines[index-3]
        movie_nums.append(movie_num) 
        

    ratings = [rating.lstrip() for rating in ratings]
    for i in range(len(ratings)):
        if ratings[i] == '':
            ratings[i] = "None"


    for i in range(len(years)):
        for j in range(len(years[i])):
            if years[i][j].isnumeric():
                number_index = years[i].find(years[i][j])
                years[i] = years[i][number_index:number_index+4]
                break


    table_data = list(zip(movie_nums, titles, years, ratings))
    # headers = ["Movie Number", "Title", "Year", "Rating"]

    # print(tabulate(table_data, headers=headers))
    
    return table_data

synopsis_list = []

# Function to get the synopsis from every movie in the webpage
def synopses(link):
    webpage = link
    response = requests.get(webpage)

    page = response.text

    soup = BeautifulSoup(page, 'html.parser')

    url_list = []
    movie_url_list = []
    movie_ref_nums = []

    # Get all the hyperlinks
    for link in soup.find_all('a'):
        url_list.append(link.get('href'))

    # Filter to get movie title hyperlinks
    for url in url_list:
        if '/title/tt' in url:
            if url not in movie_url_list:
                movie_url_list.append(url) 

    # Take the reference number from the movie url
    for movie_url in movie_url_list:
        movie_ref_nums.append(movie_url[7:16])


    # Extract the synopsis from every movie then append to a list
    driver = webdriver.Chrome('/Users/nixoncarino/Desktop/chromedriver')

    for i in movie_ref_nums:
        url = "https://www.imdb.com/title/" + i + "/plotsummary/?ref_=tt_stry_pl#synopsis"
        try:
            driver.get(url)
            synopsis_element = driver.find_element(By.XPATH, '//*[@id="__next"]/main/div/section/div/section/div/div[1]/section[2]/div[2]/ul/li/div/div/div/div/div')
        except:
            synopsis_list.append("No Synopsis")
        else:
            synopsis = synopsis_element.text
            synopsis_list.append(synopsis)

# Function that find family related words on the synopsis
def text_search(synopsis_list):
    # The indices of the synopses that contain any of the keywords
    match_index_list = []

    keywords = ["family", "parenting", "father", "mother", "son", "daughter", "sibling", "brother", "sister", "marriage", "divorce", "blended family", "adoption",
                "foster care", "custody", "inheritance", "legacy", "generations", "multigenerational", "family reunion", "family secrets", "family drama", "dysfunctional", 
                "dysfunctional family", "family conflict", "family relationships", "family values", "family ties", "parent-child relationship", "relationship",
                "coming-of-age", "parenthood", "growing up", "childhood", "teenage years", "aging parents", "grandparents"]

    for i in range(len(synopsis_list)):
        for keyword in keywords:
            if keyword in synopsis_list[i]:
                if i not in match_index_list:
                    match_index_list.append(i)

    return match_index_list

# Call synopses function to put all synopses into list
synopses("https://www.imdb.com/search/title/?title_type=feature&num_votes=25000,&genres=adventure&view=simple")
synopses("https://www.imdb.com/search/title/?title_type=feature&num_votes=25000,&genres=adventure&view=simple&start=51&ref_=adv_nxt")

# Create Data Frame for Movie information
df_animation_1 = pd.DataFrame(movie_table("https://www.imdb.com/search/title/?title_type=feature&num_votes=25000,&genres=adventure&view=simple"), 
                            columns=['Index', 'Title', 'Year', 'Rating'])
df_animation_2 = pd.DataFrame(movie_table("https://www.imdb.com/search/title/?title_type=feature&num_votes=25000,&genres=adventure&view=simple&start=51&ref_=adv_nxt"), 
                            columns=['Index', 'Title', 'Year', 'Rating'])
df_animation = pd.concat([df_animation_1, df_animation_2], ignore_index=True).assign(Genre='Adventure', Synopsis=synopsis_list)

# Output information of movies that contain family keywords
pd.set_option('display.max_rows', None)
df_animation.iloc[text_search(synopsis_list)]
# Out:
#    Index                                              Title  Year Rating  \
# 0     1.                        The Super Mario Bros. Movie  2023    7.3
# 1     2.            Dungeons & Dragons: Honor Among Thieves  2023    7.6
# 3     4.                           Avatar: The Way of Water  2022    7.7
# 6     7.                  Everything Everywhere All at Once  2022    7.9
# 9    10.                                       Interstellar  2014    8.6
# 10   11.              Harry Potter and the Sorcerer's Stone  2001    7.6
# 11   12.                                               Dune  2021      8
# 12   13.                                          Inception  2010    8.8
# 13   14.                                              Plane  2023    6.5
# 14   15.                     Black Panther: Wakanda Forever  2022    6.7
# 15   16.  The Lord of the Rings: The Fellowship of the Ring  2001    8.8
# 16   17.                                    The Blue Lagoon  1980    5.8
# 17   18.                                             Avatar  2009    7.9
# 19   20.                                            Shazam!  2019      7
# 20   21.                                          Gladiator  2000    8.5
# 21   22.                                  Avengers: Endgame  2019    8.4
# 22   23.                                            Twister  1996    6.4
# 23   24.                                  The Suicide Squad  2021    7.2
# 24   25.                                   The Hunger Games  2012    7.2
# 25   26.      The Lord of the Rings: The Return of the King  2003      9
# 26   27.                           Jurassic World: Dominion  2022    5.6
# 27   28.                               Inglourious Basterds  2009    8.3
# 28   29.                                     No Time to Die  2021    7.3
# 30   31.                            Guardians of the Galaxy  2014      8
# 31   32.                                          Time Trap  2017    6.2
# 32   33.                                         Game Night  2018    6.9
# 34   35.                                         Black Adam  2022    6.3
# 35   36.                                      Jurassic Park  1993    8.2
# 36   37.                                 Back to the Future  1985    8.5
# 38   39.                                               Hook  1991    6.8
# 39   40.                                 The Princess Bride  1987      8
# 40   41.                                          Star Wars  1977    8.6
# 41   42.                                 Mad Max: Fury Road  2015    8.1
# 42   43.                           The Grand Budapest Hotel  2014    8.1
# 44   45.                  Spider-Man: Into the Spider-Verse  2018    8.4
# 45   46.  Pirates of the Caribbean: The Curse of the Bla...  2003    8.1
# 46   47.                                       Galaxy Quest  1999    7.4
# 47   48.                                         Spider-Man  2002    7.4
# 49   50.                   Star Wars: The Rise Of Skywalker  2019    6.5
# 50   51.                                   Ready Player One  2018    7.4
# 51   52.                                      Suicide Squad  2016    5.9
# 52   53.                                             Sing 2  2021    7.4
# 53   54.                       Rogue One: A Star Wars Story  2016    7.8
# 54   55.                            Raiders of the Lost Ark  1981    8.4
# 55   56.                                           Free Guy  2021    7.1
# 56   57.                                  The Fifth Element  1997    7.6
# 58   59.                Harry Potter and the Goblet of Fire  2005    7.7
# 59   60.                              2001: A Space Odyssey  1968    8.3
# 60   61.                             Exodus: Gods and Kings  2014      6
# 61   62.              The Lord of the Rings: The Two Towers  2002    8.8
# 62   63.          Star Wars: Episode I - The Phantom Menace  1999    6.5
# 64   65.        Doctor Strange in the Multiverse of Madness  2022    6.9
# 65   66.                                        The Martian  2015      8
# 66   67.                                      Spirited Away  2001    8.6
# 67   68.                                              Moana  2016    7.6
# 68   69.                                           Eternals  2021    6.3
# 69   70.                 Captain America: The First Avenger  2011    6.9
# 70   71.                                      Chaos Walking  2021    5.7
# 71   72.                                      The Lion King  1994    8.5
# 72   73.                                      Lilo & Stitch  2002    7.3
# 73   74.   Pirates of the Caribbean: Dead Men Tell No Tales  2017    6.5
# 74   75.                     Jumanji: Welcome to the Jungle  2017    6.9
# 75   76.                                             Aliens  1986    8.4
# 76   77.                                        Stand by Me  1986    8.1
# 77   78.                      Mission: Impossible - Fallout  2018    7.7
# 78   79.                                          Uncharted  2022    6.3
# 79   80.                             Avengers: Infinity War  2018    8.4
# 80   81.           Harry Potter and the Prisoner of Azkaban  2004    7.9
# 81   82.                                      Power Rangers  2017    5.9
# 83   84.                              Smokey and the Bandit  1977      7
# 84   85.                                          The Mummy  1999    7.1
# 85   86.       Harry Potter and the Deathly Hallows: Part 2  2011    8.1
# 86   87.                                    A Knight's Tale  2001    6.9
# 87   88.         Star Wars: Episode VI - Return of the Jedi  1983    8.3
# 88   89.                                     The King's Man  2021    6.3
# 89   90.                                    The Parent Trap  1998    6.6
# 90   91.                  The Hobbit: An Unexpected Journey  2012    7.8
# 91   92.                                   Independence Day  1996      7
# 93   94.                                               Cars  2006    7.2
# 94   95.                                           Zootopia  2016      8
# 95   96.         Star Wars: Episode VII - The Force Awakens  2015    7.8
# 96   97.                        Kingsman: The Golden Circle  2017    6.7
# 97   98.                                           Superman  1978    7.4
# 99  100.                    The Hunger Games: Catching Fire  2013    7.5
#
#         Genre                                           Synopsis
# 0   Adventure  Italian-American brothers Mario and Luigi have...
# 1   Adventure  Prior to imprisonment, bard Edgin Darvis serve...
# 3   Adventure  Over a decade after the events of the first fi...
# 6   Adventure  Part 1: Everything\n\nEvelyn Wang (Yeoh) is a ...
# 9   Adventure  A group of elderly people are giving interview...
# 10  Adventure  Lord Voldemort, an evil and powerful dark wiza...
# 11  Adventure  The story opens with a woman telling a portion...
# 12  Adventure  A young man, exhausted and delirious, washes u...
# 13  Adventure  The film opens with Captain Brodie Torrance (G...
# 14  Adventure  In 1571, the Yucatán people fell ill to the pl...
# 15  Adventure  The prologue, spoken by Galadriel, shows the D...
# 16  Adventure  It is the Victorian era in the South Pacific. ...
# 17  Adventure  The story opens with a sweeping shot high acro...
# 19  Adventure  In Winter 1974. a young Thaddeus Sivana and hi...
# 20  Adventure  Shouting "Roma victor!" as his forces attack, ...
# 21  Adventure  In the opening, Clint Barton is teaching his d...
# 22  Adventure  In June 1969, a young family takes shelter fro...
# 23  Adventure  The film opens at Belle Reve Penitentiary wher...
# 24  Adventure  The nation of Panem is divided into 12 distric...
# 25  Adventure  In the opening scene: a flashback shows two ho...
# 26  Adventure  Four years after dinosaurs have been set loose...
# 27  Adventure  Chapter One: "Once Upon a Time..... in Nazi-Oc...
# 28  Adventure  A young Madeleine Swann witnesses the murder o...
# 30  Adventure  Earth, 1988:\n\nYoung Peter Quill (Wyatt Oleff...
# 31  Adventure  Students Taylor and Jackie, along with their f...
# 32  Adventure  The film starts with a trivia night competitio...
# 34  Adventure  Five thousand years ago, the city of Kahndaq w...
# 35  Adventure  The story begins on Isla Nublar, a small islan...
# 36  Adventure  The title logo appears on a black background. ...
# 38  Adventure  It is the present day, and the boy who was onc...
# 39  Adventure  Fairy tale story-within-a-story with an all-st...
# 40  Adventure  Note: Italicized paragraphs describe scenes ad...
# 41  Adventure  Max Rockatansky (Tom Hardy) explains in a voic...
# 42  Adventure  A young woman walks into a cemetery in the Rep...
# 44  Adventure  This animated film starts with Peter Parker (v...
# 45  Adventure  As Governor Weatherby Swann and his twelve-yea...
# 46  Adventure  Galaxy Quest was once a popular geek televisio...
# 47  Adventure  Peter Benjamin Parker (Tobey Maguire) is a ner...
# 49  Adventure  The opening crawl reveals that a mysterious br...
# 50  Adventure  We open in a place called "The Stacks", in Col...
# 51  Adventure  The film opens at the Belle Reve Penitentiary....
# 52  Adventure  Some time after the events of the first film, ...
# 53  Adventure  The film begins with the traditional text: A L...
# 54  Adventure  In the spring of 1936 an exploration party pen...
# 55  Adventure  Free City is an online, open-world video game ...
# 56  Adventure  The story's premise is that every five thousan...
# 58  Adventure  Harry, Ron and Hermione enter their fourth yea...
# 59  Adventure  To Richard Strauss' tone poem "Thus Spake Zara...
# 60  Adventure  Ancient Egypt 1,300 B.C.\n\nThe Hebrews have b...
# 61  Adventure  The story opens with a flashback to the first ...
# 62  Adventure  The opening crawl reveals that the Trade Feder...
# 64  Adventure  In the Gap Junction, the space between univers...
# 65  Adventure  At the landing site of the shuttle Ares III, A...
# 66  Adventure  Ten-year-old Chihiro (voice: Daveigh Chase in ...
# 67  Adventure  Using a tapa cloth to animate her story, Gramm...
# 68  Adventure  In 5000 B.C., a group of ten immortal individu...
# 69  Adventure  Bright headlights cut through a thick sheet of...
# 70  Adventure  In the year 2257 AD, the men of the planet New...
# 71  Adventure  The Lion King takes place in the Pride Lands o...
# 72  Adventure  Somewhere on a distant planet, a court is call...
# 73  Adventure  In the opening scene, young Henry Turner (Lewi...
# 74  Adventure  In 1996, teenager Alex Vreeke (Mason Guccione)...
# 75  Adventure  After the opening credits, we see a spacecraft...
# 76  Adventure  A man (Richard Dreyfuss) sits in his car readi...
# 77  Adventure  The film opens with Ethan and Julia getting ma...
# 78  Adventure  Orphaned brothers Sam and Nathan "Nate" Drake ...
# 79  Adventure  SPOILER: Thanos and his Children - Proxima Mid...
# 80  Adventure  It opens at the Dursleys' home where Harry Pot...
# 81  Adventure  The film opens in the Cenozoic Era on Earth. A...
# 83  Adventure  Bo Darville, aka The Bandit, is a semi-retired...
# 84  Adventure  In Egypt, circa 1290 BC, high priest Imhotep e...
# 85  Adventure  After burying Dobby at the garden of the Shell...
# 86  Adventure  (As it was said, may contain SPOILERS. Well, I...
# 87  Adventure  The opening crawl reveals that Han Solo's frie...
# 88  Adventure  In 1902, aristocrat Orlando, Duke of Oxford, h...
# 89  Adventure  In 1986, Nick Parker (Dennis Quaid) and Elizab...
# 90  Adventure  Prologue: During the preparations for the birt...
# 91  Adventure  On July 2, a giant alien mother ship, over 340...
# 93  Adventure  The movie begins with two announcers, Bob Cutl...
# 94  Adventure  In the town of Bunnyburrow, 9 year old bunny, ...
# 95  Adventure  Luke Skywalker has vanished. In his absence, t...
# 96  Adventure  The film opens with Eggsy, A.K.A. Galahad (Tar...
# 97  Adventure  Note: italicized text denotes extended scenes ...
# 99  Adventure  Six months after winning the 74th Hunger Games...
