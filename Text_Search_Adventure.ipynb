# %%
import requests
from bs4 import BeautifulSoup
from tabulate import tabulate
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By

''' 
This program merges all of the separate programs (protagonists.ipynb and synopsis.ipynb) and adds the text search function. It will
return all of the movies that contain family keywords inside a data frame. This program runs in approximately 7-8 mins."
'''

def movie_table(url):
    webpage = url
    response = requests.get(webpage)

    page = response.text

    soup = BeautifulSoup(page, 'html.parser')
    beautiful_page = soup.get_text()

    ratings = []
    years = []
    titles = []
    movie_nums = []

    lines = beautiful_page.splitlines()

    for line in lines:
        if "(20" in line and ")" in line or '(19' in line and ')' in line:
            years.append(line)

    rep_years = []
    nrep_years = []
    year_indices = []

    for year in years:
        
        if lines.count(year) > 1:
            if year not in rep_years:
                rep_years.append(year)
        if lines.count(year) == 1:
            nrep_years.append(year)

    for i in range(len(rep_years)):
        first_instance = lines.index(rep_years[i])
        year_indices.append(first_instance)

        for j, item in enumerate(lines[first_instance+1:], start=first_instance+1):
            if item == rep_years[i]:
                year_indices.append(j)

    for year in nrep_years:
        if year in lines:
            index = lines.index(year)
            year_indices.append(index)


    for index in sorted(year_indices):
        title = lines[index-1]
        titles.append(title)

        rating = lines[index+6]
        ratings.append(rating)

        movie_num = lines[index-3]
        movie_nums.append(movie_num) 
        

    ratings = [rating.lstrip() for rating in ratings]
    for i in range(len(ratings)):
        if ratings[i] == '':
            ratings[i] = "None"


    for i in range(len(years)):
        for j in range(len(years[i])):
            if years[i][j].isnumeric():
                number_index = years[i].find(years[i][j])
                years[i] = years[i][number_index:number_index+4]
                break


    table_data = list(zip(movie_nums, titles, years, ratings))
    # headers = ["Movie Number", "Title", "Year", "Rating"]

    # print(tabulate(table_data, headers=headers))
    
    return table_data

synopsis_list = []

# Function to get the synopsis from every movie in the webpage
def synopses(link):
    webpage = link
    response = requests.get(webpage)

    page = response.text

    soup = BeautifulSoup(page, 'html.parser')

    url_list = []
    movie_url_list = []
    movie_ref_nums = []

    # Get all the hyperlinks
    for link in soup.find_all('a'):
        url_list.append(link.get('href'))

    # Filter to get movie title hyperlinks
    for url in url_list:
        if '/title/tt' in url:
            if url not in movie_url_list:
                movie_url_list.append(url) 

    # Take the reference number from the movie url
    for movie_url in movie_url_list:
        movie_ref_nums.append(movie_url[7:16])


    # Extract the synopsis from every movie then append to a list
    driver = webdriver.Chrome('/Users/nixoncarino/Desktop/chromedriver')

    for i in movie_ref_nums:
        url = "https://www.imdb.com/title/" + i + "/plotsummary/?ref_=tt_stry_pl#synopsis"
        try:
            driver.get(url)
            synopsis_element = driver.find_element(By.XPATH, '//*[@id="__next"]/main/div/section/div/section/div/div[1]/section[2]/div[2]/ul/li/div/div/div/div/div')
        except:
            synopsis_list.append("No Synopsis")
        else:
            synopsis = synopsis_element.text
            synopsis_list.append(synopsis)

# Function that find family related words on the synopsis
def text_search(synopsis_list):
    # The indices of the synopses that contain any of the keywords
    match_index_list = []

    keywords = ["family", "parenting", "father", "mother", "son", "daughter", "sibling", "brother", "sister", "marriage", "divorce", "blended family", "adoption",
                "foster care", "custody", "inheritance", "legacy", "generations", "multigenerational", "family reunion", "family secrets", "family drama", "dysfunctional", 
                "dysfunctional family", "family conflict", "family relationships", "family values", "family ties", "parent-child relationship", "relationship",
                "coming-of-age", "parenthood", "growing up", "childhood", "teenage years", "aging parents", "grandparents"]

    for i in range(len(synopsis_list)):
        for keyword in keywords:
            if keyword in synopsis_list[i]:
                if i not in match_index_list:
                    match_index_list.append(i)

    return match_index_list

# Call synopses function to put all synopses into list
synopses("https://www.imdb.com/search/title/?title_type=feature&num_votes=25000,&genres=adventure&view=simple")
synopses("https://www.imdb.com/search/title/?title_type=feature&num_votes=25000,&genres=adventure&view=simple&start=51&ref_=adv_nxt")

# Create Data Frame for Movie information
df_adventure_1 = pd.DataFrame(movie_table("https://www.imdb.com/search/title/?title_type=feature&num_votes=25000,&genres=adventure&view=simple"), 
                            columns=['Index', 'Title', 'Year', 'Rating'])
df_adventure_2 = pd.DataFrame(movie_table("https://www.imdb.com/search/title/?title_type=feature&num_votes=25000,&genres=adventure&view=simple&start=51&ref_=adv_nxt"), 
                            columns=['Index', 'Title', 'Year', 'Rating'])
df_adventure = pd.concat([df_adventure_1, df_adventure_2], ignore_index=True).assign(Genre='Adventure', Synopsis=synopsis_list)

# Output information of movies that contain family keywords
pd.set_option('display.max_rows', None)
df_adventure.iloc[text_search(synopsis_list)]
# Out:
# /var/folders/_2/zj00cgg95ts6m3mqz4zzzxym0000gn/T/ipykernel_33593/492598954.py:122: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/nixoncarino/Desktop/chromedriver')
#    Index                                              Title  Year Rating
# 0     1.                     Guardians of the Galaxy Vol. 3  2023    8.3  \
# 1     2.            Dungeons & Dragons: Honor Among Thieves  2023    7.4
# 3     4.                            Guardians of the Galaxy  2014      8
# 5     6.                     Guardians of the Galaxy Vol. 2  2017    7.6
# 7     8.                                               Dune  2021      8
# 8     9.                           Avatar: The Way of Water  2022    7.7
# 9    10.                  Everything Everywhere All at Once  2022    7.9
# 11   12.                                  The Suicide Squad  2021    7.2
# 12   13.                                       Interstellar  2014    8.6
# 15   16.                                  Avengers: Endgame  2019    8.4
# 19   20.                                          Inception  2010    8.8
# 20   21.              Harry Potter and the Sorcerer's Stone  2001    7.6
# 21   22.                                Conan the Barbarian  1982    6.9
# 22   23.                                   The Hunger Games  2012    7.2
# 23   24.                     Black Panther: Wakanda Forever  2022    6.7
# 24   25.                 Star Wars: Episode IV - A New Hope  1977    8.6
# 25   26.  The Lord of the Rings: The Fellowship of the Ring  2001    8.8
# 26   27.                  Spider-Man: Into the Spider-Verse  2018    8.4
# 27   28.                             Avengers: Infinity War  2018    8.4
# 28   29.                                          Idiocracy  2006    6.5
# 29   30.                                          Gladiator  2000    8.5
# 30   31.                                              Plane  2023    6.5
# 31   32.                       Kingsman: The Secret Service  2014    7.7
# 33   34.          Star Wars: Episode I - The Phantom Menace  1999    6.5
# 91   92.       Star Wars: Episode II - Attack of the Clones  2002    6.6
# 92   93.                                      Spirited Away  2001    8.6
# 93   94.                              2001: A Space Odyssey  1968    8.3
# 94   95.                                             Aliens  1986    8.4
# 95   96.                                      Suicide Squad  2016    5.9
# 96   97.                             Mechanic: Resurrection  2016    5.7
# 97   98.                                         Prometheus  2012      7
# 98   99.                                          Spartacus  1960    7.9
# 99  100.            Star Wars: Episode VIII - The Last Jedi  2017    6.9
#
#         Genre                                           Synopsis
# 0   Adventure  As a baby raccoon, Rocket is a test subject fo...
# 1   Adventure  Prior to imprisonment, bard Edgin Darvis serve...
# 3   Adventure  Earth, 1988:\n\nYoung Peter Quill (Wyatt Oleff...
# 5   Adventure  Missouri, Planet Earth, 1980\n\nMeredith Quill...
# 7   Adventure  The story opens with a woman telling a portion...
# 8   Adventure  Over a decade after the events of the first fi...
# 9   Adventure  Part 1: Everything\n\nEvelyn Wang (Yeoh) is a ...
# 11  Adventure  The film opens at Belle Reve Penitentiary wher...
# 12  Adventure  A group of elderly people are giving interview...
# 15  Adventure  In the opening, Clint Barton is teaching his d...
# 19  Adventure  A young man, exhausted and delirious, washes u...
# 20  Adventure  Lord Voldemort, an evil and powerful dark wiza...
# 21  Adventure  During the Hyborean age, "a time of high adven...
# 22  Adventure  The nation of Panem is divided into 12 distric...
# 23  Adventure  In 1571, the Yucatán people fell ill to the pl...
# 24  Adventure  Note: Italicized paragraphs describe scenes ad...
# 25  Adventure  The prologue, spoken by Galadriel, shows the D...
# 26  Adventure  This animated film starts with Peter Parker (v...
# 27  Adventure  SPOILER: Thanos and his Children - Proxima Mid...
# 28  Adventure  The narrator (Earl Mann) explains that natural...
# 29  Adventure  Shouting "Roma victor!" as his forces attack, ...
# 30  Adventure  The film opens with Captain Brodie Torrance (G...
# 31  Adventure  1997 - A helicopter flies into a compound in t...
# 33  Adventure  The opening crawl reveals that the Trade Feder...
# 34  Adventure  The opening crawl reveals that a mysterious br...
# 35  Adventure  In the distant future, several hundred years a...
# 36  Adventure  Chapter One: "Once Upon a Time..... in Nazi-Oc...
# 37  Adventure  It is the present day, and the boy who was onc...
# 38  Adventure  A man (Logan Miller) is seen trying to escape ...
# 39  Adventure  The title logo appears on a black background. ...
# 40  Adventure  The story begins on Isla Nublar, a small islan...
# 41  Adventure  In the opening monologue, Princess Irulan (Vir...
# 42  Adventure  After escaping the "sole survivor" escape room...
# 43  Adventure  A young woman walks into a cemetery in the Rep...
# 44  Adventure  Peter Benjamin Parker (Tobey Maguire) is a ner...
# 45  Adventure  The film opens in New York City the Avengers b...
# 46  Adventure  The opening crawl reveals that Han Solo's frie...
# 48  Adventure  The story opens with a sweeping shot high acro...
# 49  Adventure  The story's premise is that every five thousan...
# 50  Adventure  A young Madeleine Swann witnesses the murder o...
